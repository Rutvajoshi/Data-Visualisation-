# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the data
data = pd.read_csv('/Users/rutvajoshi/Documents/Masters final project/all_comments_new.csv')

# %%
data.head()
# Out:
#        prompt                                    discussion_link  \
# 0  Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
# 1  Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
# 2  Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
# 3  Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
# 4  Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
#
#                                              comment Month  Date    Year
# 0                        Andy has lost his marbles!!   Sep  21.0  2017.0
# 1                       New BYD Atto 3 Electric 2023   Oct  31.0  2022.0
# 2  Skoda Enyaq iv80 for 24hrs review and real-wor...   Oct  31.0  2022.0
# 3  Bilexperten Bosch repaired broken heater in 20...   Nov   1.0  2022.0
# 4  MG electric car news: MG4 oil leaks, shipping ...   Nov   1.0  2022.0

# %%
print(data.columns)
# Out:
# Index(['prompt', 'discussion_link', 'comment', 'Month', 'Date', 'Year'], dtype='object')

# %%
# Drop rows with invalid month names (optional)
data = data[data['Month'].isin(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])]

# %%
# Replace any incorrect or alternative month names with the correct ones (optional)
# For example, replace 'January' with 'Jan', 'Sept' with 'Sep', etc.
data['Month'] = data['Month'].replace({
    'January': 'Jan',
    'February': 'Feb',
    'March': 'Mar',
    'April': 'Apr',
    'May': 'May',
    'June': 'Jun',
    'July': 'Jul',
    'August': 'Aug',
    'September': 'Sep',
    'Sept': 'Sep',
    'October': 'Oct',
    'November': 'Nov',
    'December': 'Dec'
})
# Out:
# /var/folders/s4/b3_xqqqd5zq94jc155st97d80000gn/T/ipykernel_18959/1112372119.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Month'] = data['Month'].replace({

# %%
# Reset the index after dropping or modifying rows
data.reset_index(drop=True, inplace=True)

# %%
# Print the cleaned DataFrame
print(data)
# Out:
#            prompt                                    discussion_link  \
# 0      Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
# 1      Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
# 2      Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
# 3      Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
# 4      Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
# ...           ...                                                ...
# 18403    Fiat+500  https://www.speakev.com/threads/ev-as-a-first-...
# 18404    Fiat+500  https://www.speakev.com/threads/ev-as-a-first-...
# 18405    Fiat+500  https://www.speakev.com/threads/ev-as-a-first-...
# 18406    Fiat+500  https://www.speakev.com/threads/ev-as-a-first-...
# 18407    Fiat+500  https://www.speakev.com/threads/ev-as-a-first-...
#
#                                                  comment Month  Date    Year
# ...

# %%
# Create a list of month names in chronological order
months_in_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
# Calculate class distribution based on the cleaned "Month" column
class_distribution = data['Month'].value_counts()

# %%
# Reindex the class distribution in chronological order
class_distribution = class_distribution.reindex(months_in_order, fill_value=0)

# %%
# Print the class distribution
print("Class Distribution based on 'Month':\n")
print(class_distribution)
# Out:
# Class Distribution based on 'Month':
#
# Jan    2321
# Feb    1326
# Mar    1783
# Apr    1658
# May    1418
# Jun    1540
# Jul    1488
# Aug    1392
# Sep    1501
# Oct    1288
# Nov    1316
# Dec    1377
# Name: Month, dtype: int64

# %%
# Plot the line chart
plt.figure(figsize=(10, 6))
class_distribution.plot(kind='line', marker='o', color='green')
plt.title('Class Distribution based on Month', fontsize=16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Class distribution based on "prompt" column
class_distribution_prompt = data['prompt'].value_counts()

# %%
# Print the class distributions
print("Class Distribution based on 'prompt':\n")
print(class_distribution_prompt)
# Out:
# Class Distribution based on 'prompt':
#
# Abarth+500     7371
# Fiat+500       6975
# Abarth+500e    4062
# Name: prompt, dtype: int64

# %%
unique_prompts = data['prompt'].value_counts()
print(unique_prompts)
# Out:
# Abarth+500     7371
# Fiat+500       6975
# Abarth+500e    4062
# Name: prompt, dtype: int64

# %%
# Plot the prompt distribution
plt.figure(figsize=(10, 6))
class_distribution_prompt.plot(kind='bar', color='skyblue')
plt.title('Class Distribution based on Car Model For speak ev', fontsize=16)
plt.xlabel('Car Model', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Filter the data for the desired year
desired_year = 2023
filtered_df = data[data["Year"] == desired_year]

# %%
# Calculate comment counts for each month
comment_counts = filtered_df["Month"].value_counts()

# %%
# Define the order of months
month_order = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

# %%
# Reorder the index of comment_counts
comment_counts = comment_counts.reindex(month_order)

# %%
# Create a bar plot of the number of comments per month for the desired year
comment_counts.plot(kind="bar")
plt.title(f"Comment Counts per Month in {desired_year}")
plt.xlabel("Month")
plt.ylabel("Comment Count")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
# Handle missing values in the "Year" column (optional)
# If you want to drop rows with missing years, use this line:
data = data.dropna(subset=['Year'])

# %%
# Convert the "Year" column to integers
# Convert the "Year" column to float (to handle float values like '2017.0')
#data['Year'] = data['Year'].astype(float)

# %%
# Print the cleaned DataFrame
print(data)
# Out:
#            prompt                                    discussion_link  \
# 0      Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
# 1      Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
# 2      Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
# 3      Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
# 4      Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
# ...           ...                                                ...
# 18405    Fiat+500  https://www.speakev.com/threads/ev-as-a-first-...
# 18406    Fiat+500  https://www.speakev.com/threads/ev-as-a-first-...
# 18407    Fiat+500  https://www.speakev.com/threads/ev-as-a-first-...
# 18408    Fiat+500  https://www.speakev.com/threads/ev-as-a-first-...
# 18409    Fiat+500  https://www.speakev.com/threads/ev-as-a-first-...
#
#                                                  comment Month  Date    Year
# ...

# %%
# Class distribution based on "Year" column
class_distribution_year = data['Year'].value_counts()

# %%
 # Convert the "Year" column to integers
#data['Year'] = data['Year'].fillna(0).astype(int)

# %%
# Sort the data based on the "Year" column in chronological order
#data.sort_values(by='Year', inplace=True)

# %%
# For example, we'll replace '0' with NaN (missing value)
#data['Year'] = data['Year'].replace(0, pd.NA)

# %%
# Convert the "Year" column to datetime data type
#data['Year'] = pd.to_datetime(data['Year'], format='%Y', errors='coerce')

# %%
# Sort the data based on the "Year" column in chronological order
#data.sort_values(by='Year', inplace=True)

# %%
# Extract the year component from the "Year" column
#data['Year'] = data['Year'].dt.year

# %%
# Class Distribution based on 'Year'
#year_counts = data['Year'].value_counts().sort_index()

# %%
# Convert the "Year" column to integers
data['Year'] = data['Year'].fillna(0).astype(int)

# %%
# Handle '0' values in the "Year" column (optional)
# For example, we'll replace '0' with NaN (missing value)
data['Year'] = data['Year'].replace(0, pd.NA)

# %%
# Filter the data for years between 2022 and 2012
year_counts = data[(data['Year'] >= 2012) & (data['Year'] <= 2023)]['Year'].value_counts().sort_index()

# %%
print("\nClass Distribution based on 'Year':\n")
print(class_distribution_year)
# Out:
# Class Distribution based on 'Year':
#
# 2022.0    3464
# 2020.0    2650
# 2019.0    2278
# 2021.0    2123
# 2018.0    2035
# 2017.0    1712
# 2023.0    1293
# 2016.0    1199
# 2015.0     880
# 2014.0     748
# 2012.0      19
# 2013.0       7
# Name: Year, dtype: int64

# %%
# Plotting the graph
plt.figure(figsize=(10, 6))
year_counts.plot(kind='bar', color='purple')
plt.title('Class Distribution based on Year (2012 to 2023)', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Summary Statistics
print("\nSummary Statistics:")
print(data.describe())
# Out:
# Summary Statistics:
#                Date          Year
# count  18408.000000  18408.000000
# mean      15.576869   2019.324261
# std        8.821800      2.496344
# min        1.000000   2012.000000
# 25%        8.000000   2018.000000
# 50%       16.000000   2020.000000
# 75%       23.000000   2022.000000
# max       31.000000   2023.000000

# %%
data.head(100)
# Out:
#         prompt                                    discussion_link  \
# 0   Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
# 1   Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
# 2   Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
# 3   Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
# 4   Abarth+500  https://www.speakev.com/threads/ev-news-rides-...
# ..         ...                                                ...
# 95  Abarth+500  https://www.speakev.com/threads/kia-e-niro-ran...
# 96  Abarth+500  https://www.speakev.com/threads/kia-e-niro-ran...
# 97  Abarth+500  https://www.speakev.com/threads/kia-e-niro-ran...
# 98  Abarth+500  https://www.speakev.com/threads/kia-e-niro-ran...
# 99  Abarth+500  https://www.speakev.com/threads/kia-e-niro-ran...
#
#                                               comment Month  Date  Year
# 0                         Andy has lost his marbles!!   Sep  21.0  2017
# ...

# %%
# Calculate the frequency distribution of dates (1 to 31)
date_counts = data['Date'].value_counts().sort_index()

# %%
# Distribution Plot - "Date" Column
plt.figure(figsize=(14, 6))
plt.hist(data['Date'], bins=20, color='lightblue', edgecolor='black')
plt.title('Distribution of Dates', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Comment Length Analysis
data['comment_length'] = data['comment'].apply(lambda x: len(x))
print("Comment Length Analysis:")
print(data[['comment', 'comment_length']].head())
# Out:
# Comment Length Analysis:
#                                              comment  comment_length
# 0                        Andy has lost his marbles!!              27
# 1                       New BYD Atto 3 Electric 2023              28
# 2  Skoda Enyaq iv80 for 24hrs review and real-wor...              82
# 3  Bilexperten Bosch repaired broken heater in 20...              66
# 4  MG electric car news: MG4 oil leaks, shipping ...              62

# %%
# Month-wise Analysis
month_wise_counts = data['Month'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
month_wise_counts.plot(kind='bar', color='orange')
plt.title('Month-wise Comment Counts', fontsize=16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Comment Count', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Filter the data for the desired car model
desired_model = "Abarth+500e"
filtered_df = data[data["prompt"] == desired_model]

# %%
# Calculate comment counts for each month
comment_counts = filtered_df["Month"].value_counts()

# %%
# Define the order of months
month_order = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

# %%
# Reorder the index of comment_counts
comment_counts = comment_counts.reindex(month_order)

# %%
# Create a bar plot of the number of comments per month for the desired car model
comment_counts.plot(kind="bar")
plt.title(f"Comment Counts per Month for {desired_model}")
plt.xlabel("Month")
plt.ylabel("Comment Count")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
# Group by year and prompt to calculate comment counts
comment_counts = data.groupby(['Year', 'prompt'])['comment'].count().reset_index()

# %%
# Pivot the data to have prompts as columns and years as rows
pivot_table = comment_counts.pivot(index='Year', columns='prompt', values='comment').fillna(0)

# %%
# Reset the index to make 'Year' a column again
pivot_table.reset_index(inplace=True)

# %%
# Filter the DataFrame to include only comments from 2012 to 2023
filtered_data = pivot_table[(pivot_table['Year'] >= 2012) & (pivot_table['Year'] <= 2023)]

# %%
# Create a line chart for the filtered data
filtered_data.plot(kind='line', x='Year', marker='o')
plt.title('Comment Counts Over Years for Different Prompts (2012-2023)')
plt.xlabel('Year')
plt.ylabel('Comment Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend(title='Prompt')
plt.show()

# %%
# Filter the data for the desired year
desired_year = 2023
filtered_df = data[data["Year"] == desired_year]

# %%
# Group by month and prompt to calculate comment counts
comment_counts = filtered_df.groupby(['Month', 'prompt'])['comment'].count().reset_index()

# %%
# Pivot the data to have prompts as columns and months as rows
pivot_table = comment_counts.pivot(index='Month', columns='prompt', values='comment').fillna(0)

# %%
# Create a line chart for the pivot table
ax = pivot_table.plot(kind='line', marker='o')
plt.title(f'Comment Counts by Prompts for the Year {desired_year}')
plt.xlabel('Month')
plt.ylabel('Comment Count')

# Set custom x-axis tick labels for abbreviated month names
month_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
plt.xticks(range(len(month_labels)), month_labels, rotation=45)

plt.legend(title='Prompt')
plt.show()
