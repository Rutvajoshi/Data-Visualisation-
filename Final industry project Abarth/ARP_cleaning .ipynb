# %%
import pandas as pd
from langdetect import detect

# %%
df = pd.read_csv('/Users/rutvajoshi/Documents/Masters final project/fiatFinaldata.csv')

# %%
# Get the number of rows and columns
num_rows = df.shape[0]
num_columns = df.shape[1]

# %%
# Print the number of rows and columns
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 6505
# Number of columns: 19

# %%
# Define a function to check if a sentence is in English
def is_english(sentence):
    try:
        if detect(sentence) == 'en':
            return True
        else:
            return False
    except:
        return False

# %%
# Apply the function to filter out non-English sentences
df['is_english'] = df['Tweet Text'].apply(is_english)
df = df[df['is_english'] == True]

# %%
# Get the number of rows and columns
num_rows = df.shape[0]
num_columns = df.shape[1]

# %%
# Print the number of rows and columns
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 2932
# Number of columns: 20

# %%
df.head(50)
# Out:
#                                            Tweet Text  \
# 2   @Naonskdnao1103 @kazzen Check out : Fiat Punto...
# 3   the virgin wolkswagen killing the beetle (oooh...
# 4   Spring crop of little EVs includes 3 you may w...
# 6   Spring crop of little EVs includes 3 you may w...
# 7   RT @oruclarahmet1: With my unique ideas &amp; ...
# 8   With my unique ideas &amp; inventions trusting...
# 9   Some cars from the archives - \nCitroen/Fiat/N...
# 10  @FD_Tweets I absolutely love it. This fits the...
# 13  @TheRealKeean @NaomiLWood So 2 in 3 cars? Have...
# 14  The Reliable Fiat Punto 👍\nCorner Heidelberg a...
# 15  Enter the All-Electric #Fiat500, a space of ch...
# 16  @TheOverBorders I used to get that in my Fiat ...
# 17  Red Convertible  SOLD----  \n2012 Fiat POP 500...
# 18  RT @WenPanda_fi: We at the $PANDA Token Compar...
# 19  ‘Mickey Mouse Car’: Fiat Revives the Topolino ...
# 22  The Porsche 914 is one of the most exciting af...
# ...

# %%
# Save the modified DataFrame to a new CSV file
df.to_csv('ARP_Abarth.csv', index=False)
