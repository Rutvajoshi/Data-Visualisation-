# %%
import tweepy
import csv
import pandas as pd 
from datetime import datetime , timedelta

# %%
CONSUMER_API_KEY  ='oBrBLWJh4Kr776rZqA9UztY0L'
CONSUMER_API_SECRET  = 'a2ZGerAmGliAmYSlDEHrJM27WyrnvSjVX3wJx8H35r5hZ27J41'
ACCESS_KEY  = '1585007487287189506-6lqM5OTYpJfdFUFpvHMlBN0nh9wkUV'
ACCESS_SECRET  = 'KGfLUdUqQ9r3uEZuShOPnklfbr9Y3VHIW9sx02zQzPtFO'

# %%
auth = tweepy.OAuthHandler(CONSUMER_API_KEY, CONSUMER_API_SECRET)
auth.set_access_token(ACCESS_KEY, ACCESS_SECRET)
api = tweepy.API(auth, wait_on_rate_limit = True)

# %%
search_query = "abarth 500"
no_of_tweets =150

# %%
try:
    #The number of tweets we want to retrieved from the search
    tweets = api.search_tweets(q=search_query, count=no_of_tweets)
    
    #Pulling Some attributes from the tweet
    attributes_container = [[tweet.user.name, tweet.created_at, tweet.favorite_count, tweet.source,  tweet.text] for tweet in tweets]

    #Creation of column list to rename the columns in the dataframe
    columns = ["User", "Date Created", "Number of Likes", "Source of Tweet", "Tweet"]
    
    #Creation of Dataframe
    tweets_df = pd.DataFrame(attributes_container, columns=columns)
except BaseException as e:
    print('Status Failed On,',str(e))

# %%
tweets_df.head (50)
# Out:
#                                           User              Date Created  \
# 0                                  Cars & Bids 2023-06-14 18:53:00+00:00
# 1                         Colleen Falco Curran 2023-06-14 18:17:24+00:00
# 2                         Colleen Falco Curran 2023-06-14 18:14:35+00:00
# 3                              @motorespuntoes 2023-06-14 18:13:43+00:00
# 4                        Company Car In Action 2023-06-14 13:45:37+00:00
# 5                                   Fleet News 2023-06-14 13:43:49+00:00
# 6   Life in the FAST LANE.@ユーチューバー / フェラーリ納車待ち 2023-06-14 13:22:56+00:00
# 7                                         Manu 2023-06-14 13:01:36+00:00
# 8                                        Matte 2023-06-14 12:44:33+00:00
# 9                                        victu 2023-06-14 11:46:28+00:00
# 10                                  Fabriziano 2023-06-14 10:21:22+00:00
# 11                            Classic Projects 2023-06-14 10:00:44+00:00
# ...

# %%
# Define the search query and maximum number of tweets
text_query = "Abarth500e"
max_tweets = 150

# Use the correct method 'search_tweets' to create a cursor
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

# Iterate over the tweets and extract desired information
tweets_list = [[tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, tweet.user.default_profile_image] for tweet in tweets]
# Creation of dataframe from tweets_list
# Add or remove columns as you remove tweet information
tweets_df2 = pd.DataFrame(tweets_list,columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
tweets_df2.head()
# Out:
#                                           Tweet Text  \
# 0  RT @central_ev: Early Xmas present? We test th...
# 1  Driven by performance? Unleash the power of el...
# 2  There’s a new Scorpion in town. Meet the New A...
# 3  RT @museo500: 【速報】ABARTH 500e 試乗レポート！\nhttps:/...
# 4  RT @museo500: 【速報】ABARTH 500e 試乗レポート！\nhttps:/...
#
#              Tweet Datetime             Tweet Id  \
# 0 2023-06-14 14:59:48+00:00  1668996668551774210
# 1 2023-06-12 18:08:19+00:00  1668319333347360775
# 2 2023-06-12 07:58:03+00:00  1668165753672024064
# 3 2023-06-10 04:15:58+00:00  1667385089150566402
# 4 2023-06-10 01:54:12+00:00  1667349413935857665
#
#                          Twitter Username  Twitter @ name  \
# 0                                alison 😼  AlisonKenley27
# 1  FJ Chalke Electric Vehicle Specialists      FJChalkeEV
# 2                F J Chalke & Vale Motors        fjchalke
# 3                          Oh多岐ええ位置＠浪漫社の男        kawasemi
# ...

# %%
# Define the search query and maximum number of tweets
text_query = "Fiat500 UK"
max_tweets = 1000

# Use the correct method 'search_tweets' to create a cursor
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

# Iterate over the tweets and extract desired information
tweets_list = [[tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, tweet.user.default_profile_image] for tweet in tweets]
# Creation of dataframe from tweets_list
# Add or remove columns as you remove tweet information
tweets_df3 = pd.DataFrame(tweets_list,columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
# Save dataframe as CSV
tweets_df3.to_csv('Fiat500UK.csv', index=False)

# %%
# Define the search query and maximum number of tweets
text_query = "Abarth500"
max_tweets = 1000

# Use the correct method 'search_tweets' to create a cursor
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

# Iterate over the tweets and extract desired information
tweets_list = [[tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, tweet.user.default_profile_image] for tweet in tweets]
# Creation of dataframe from tweets_list
# Add or remove columns as you remove tweet information
tweets_df4 = pd.DataFrame(tweets_list,columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
# Save dataframe as CSV
tweets_df4.to_csv('abarth500.csv', index=False)

# %%
# Define the search query and maximum number of tweets
text_query = "Fiat cars"
max_tweets = 1000

# Use the correct method 'search_tweets' to create a cursor
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

# Iterate over the tweets and extract desired information from users located in the UK
tweets_list = []
for tweet in tweets:
    if tweet.user.location and "united kingdom" in tweet.user.location.lower():
        tweets_list.append([tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                            tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                            tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                            tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                            tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, tweet.user.default_profile_image])

# Creation of dataframe from tweets_list
# Add or remove columns as you remove tweet information
tweets_df5 = pd.DataFrame(tweets_list, columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                               'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                               'User Verified Status', 'Users Following Count',
                                               'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                               'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                               'User Default Profile', 'User Default Profile Image'])

# %%
# Save dataframe as CSV
tweets_df5.to_csv('Fiat1cars.csv', index=False)

# %%
# Define the search query and maximum number of tweets
text_query = "Fiat cars"
max_tweets = 1000

# Use the correct method 'search_tweets' to create a cursor
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

# Iterate over the tweets and extract desired information
tweets_list = [[tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, tweet.user.default_profile_image] for tweet in tweets]
# Creation of dataframe from tweets_list
# Add or remove columns as you remove tweet information
tweets_df6 = pd.DataFrame(tweets_list,columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
tweets_df6.head()
# Out:
#                                           Tweet Text  \
# 0  @KooshyKooo @SURANOM1 @valuemanmatt @Dylanfitz...
# 1  RT @saifedean: Fiat cartel blogger argues infl...
# 2  RT @saifedean: Fiat cartel blogger argues infl...
# 3  RT @saifedean: Fiat cartel blogger argues infl...
# 4  RT @saifedean: Fiat cartel blogger argues infl...
#
#              Tweet Datetime             Tweet Id   Twitter Username  \
# 0 2023-06-14 21:21:48+00:00  1669092802301444097    benny the iron.
# 1 2023-06-14 21:09:26+00:00  1669089689976930305         kryptiikki
# 2 2023-06-14 21:01:55+00:00  1669087798530392064  HasoforSoundMoney
# 3 2023-06-14 21:00:23+00:00  1669087411702308867    ScheterPiff_btc
# 4 2023-06-14 20:53:33+00:00  1669085689143521281    FrancisBothwell
#
#     Twitter @ name      Twitter User Id Twitter User Location  \
# 0        figjamben             31183899               ireland
# 1       kryptiikki  1346107964038537217
# 2           Haso4M  1286992618635661312             Australia
# ...

# %%
# Define the search query and maximum number of tweets
text_query = "Fiat500X"
max_tweets = 1000

# Use the correct method 'search_tweets' to create a cursor
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

# Iterate over the tweets and extract desired information
tweets_list = [[tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, tweet.user.default_profile_image] for tweet in tweets]
# Creation of dataframe from tweets_list
# Add or remove columns as you remove tweet information
tweets_df7 = pd.DataFrame(tweets_list,columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
tweets_df7.head()
# Out:
#                                           Tweet Text  \
# 0   MINIクロスオーバーとかFIAT500xとか乗る人の気持ちはわからん。\n仲良くはなれんタイプ
# 1           @FINALLEVEL Via grande #Fiat500X \n🧞‍♂️🙀
# 2  💸 Per il recente 1.5 da 130 CV c’è uno sconto ...
# 3  @FIAT_JP 将来的にFIAT500Xに乗りたいと思っています🙋‍♀️\n街中を毎日走る...
#
#              Tweet Datetime             Tweet Id   Twitter Username  \
# 0 2023-06-14 06:51:35+00:00  1668873802959437825                S.
# 1 2023-06-10 15:50:48+00:00  1667559947981275137     Grebille Diane
# 2 2023-06-07 10:00:00+00:00  1666384505509142529  Motor1.com Italia
# 3 2023-06-06 05:56:39+00:00  1665960876158091265           SS〻まい💜🐶🍊
#
#   Twitter @ name      Twitter User Id Twitter User Location  \
# 0  sayonaraanoko            105444314                    地球
# 1   muskCheshire  1515696326373224453         Paris, France
# 2   Motor1italia             78624867                Italia
# 3         maiokw           3140376751                    日本
#
# ...

# %%
# Save dataframe as CSV
tweets_df7.to_csv('Fiat500x.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Save dataframe as CSV
# ----> 2 tweets_df7.to_csv('Fiat500x.csv', index=False)
#
# NameError: name 'tweets_df7' is not defined

# %%
# Define the search query and maximum number of tweets
text_query = "fiat automobiles"
max_tweets = 1000

# Use the correct method 'search_tweets' to create a cursor
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

# Iterate over the tweets and extract desired information
tweets_list = [[tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, tweet.user.default_profile_image] for tweet in tweets]
# Creation of dataframe from tweets_list
# Add or remove columns as you remove tweet information
tweets_df8 = pd.DataFrame(tweets_list,columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
tweets_df8.head()
# Out:
#                                           Tweet Text  \
# 0  RT @oruclarahmet1: @ds_automobiles @MGmotor @r...
# 1  @ds_automobiles @MGmotor @renault_fr\n@Citroen...
# 2  @repubblica Molinari, ha chiesto l'autorizzazi...
# 3  RT @oruclarahmet1: With my unique ideas &amp; ...
# 4  With my unique ideas &amp; inventions trusting...
#
#              Tweet Datetime             Tweet Id Twitter Username  \
# 0 2023-06-11 09:31:05+00:00  1667826781011705856      Design GURU
# 1 2023-06-11 09:30:58+00:00  1667826747729952768      Design GURU
# 2 2023-06-10 23:40:41+00:00  1667678199394779136     Gianburrasca
# 3 2023-06-10 10:56:11+00:00  1667485806200598533      Design GURU
# 4 2023-06-10 10:56:01+00:00  1667485763406110721      Design GURU
#
#   Twitter @ name      Twitter User Id Twitter User Location URL in Bio  \
# 0  oruclarahmet1  1049633325718138880      Istanbul, Turkey       None
# 1  oruclarahmet1  1049633325718138880      Istanbul, Turkey       None
# ...

# %%
# Save dataframe as CSV
tweets_df8.to_csv('Fiatautomobiles.csv', index=False)

# %%
# Define the search query and maximum number of tweets
text_query = "fiat 500 sport"
max_tweets = 1000

# Use the correct method 'search_tweets' to create a cursor
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

# Iterate over the tweets and extract desired information
tweets_list = [[tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, tweet.user.default_profile_image] for tweet in tweets]
# Creation of dataframe from tweets_list
# Add or remove columns as you remove tweet information
tweets_df9 = pd.DataFrame(tweets_list,columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
tweets_df9.head()
# Out:
#                                           Tweet Text  \
# 0  RT @marydebeck: #Xalapa #Venta Fiat 500 2013 s...
# 1  RT @marydebeck: #Xalapa #Venta Fiat 500 2013 s...
# 2  RT @marydebeck: #Xalapa #Venta Fiat 500 2013 s...
# 3  RT @marydebeck: #Xalapa #Venta Fiat 500 2013 s...
# 4  RT @marydebeck: #Xalapa #Venta Fiat 500 2013 s...
#
#              Tweet Datetime             Tweet Id  \
# 0 2023-06-09 04:31:39+00:00  1667026649982836736
# 1 2023-06-09 03:54:56+00:00  1667017407964094470
# 2 2023-06-09 00:37:45+00:00  1666967786583646209
# 3 2023-06-08 22:16:13+00:00  1666932169594339331
# 4 2023-06-08 20:01:47+00:00  1666898335792259094
#
#                         Twitter Username   Twitter @ name Twitter User Id  \
# 0                      ALBERTO RAMOS MEN  Albertoramosmen       115812913
# 1  Feto de PicaFresa🍓 (aborto mal hecho)        RoxanaAAT       549825729
# 2                                    Yas       yasminmn53      2524606697
# ...

# %%
# Save dataframe as CSV
tweets_df9.to_csv('Fiatsports.csv', index=False)

# %%
# Define the search query and maximum number of tweets
text_query = "Fiat 500 hybrid"
max_tweets = 1000

# Use the correct method 'search_tweets' to create a cursor
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

# Iterate over the tweets and extract desired information
tweets_list = [[tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, tweet.user.default_profile_image] for tweet in tweets]
# Creation of dataframe from tweets_list
# Add or remove columns as you remove tweet information
tweets_df10 = pd.DataFrame(tweets_list,columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
tweets_df10.head()
# Out:
#                                           Tweet Text  \
# 0  2021 FIAT 500 LOUNGE 1.0 MHEV EURO 6 AP 3DR\nS...
# 1  RT @fiat: With Fiat Panda Hybrid &amp; 500 Hyb...
# 2  RT @Lesley_A: SUPERB 2021 FIAT 500 LOUNGE MHEV...
# 3  RT @Lesley_A: STUNNING 2021 FIAT 500 LOUNGE MH...
# 4  @KateFantom @RichardMR64 @Gill_Nowell @She_sEl...
#
#              Tweet Datetime             Tweet Id  \
# 0 2023-06-10 10:36:35+00:00  1667480876475723776
# 1 2023-06-09 17:37:53+00:00  1667224508543934473
# 2 2023-06-08 11:27:48+00:00  1666768990180372481
# 3 2023-06-06 13:56:36+00:00  1666081657940774918
# 4 2023-06-06 08:15:08+00:00  1665995728211046401
#
#                                     Twitter Username Twitter @ name  \
# 0                        Lesley Anderson:)🏴󠁧󠁢󠁳󠁣󠁴󠁿🇺🇦🌻       Lesley_A
# 1  WoodwardWyrtunMitchamCalmFreshmanAndNotAntisemite   wernerludvik
# 2                        Lesley Anderson:)🏴󠁧󠁢󠁳󠁣󠁴󠁿🇺🇦🌻       Lesley_A
# 3                        Lesley Anderson:)🏴󠁧󠁢󠁳󠁣󠁴󠁿🇺🇦🌻       Lesley_A
# ...

# %%
# Save dataframe as CSV
tweets_df10.to_csv('Fiathybrid.csv', index=False)

# %%
text_query = "Fiat 500 Electric"
max_tweets = 1000 # Maximum number of tweets to scrape

# %%
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

tweets_list = []
for tweet in tweets:
    tweets_list.append([tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, 
            tweet.user.default_profile_image])

# %%
tweets_df11 = pd.DataFrame(tweets_list, columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
tweets_df11.head(100)
# Out:
#                                            Tweet Text  \
# 0   @LocalBateman Just add the V12 era F1 car soun...
# 1   Fiat 600e: here are the first images of the el...
# 2   the virgin wolkswagen killing the beetle (oooh...
# 3   Enter the All-Electric #Fiat500, a space of ch...
# 4   ⁦@RealJodieKidd⁩ ⁦@DanniMenzies⁩ ⁦@PaulONeill2...
# 5   Concorso Iper Vai Col Green 2023: in palio Jee...
# 6   Concorso Iper Vai Col Green 2023: in palio Jee...
# 7   Just arrived at Pro Sports Cars, Fiat 500 Pop ...
# 8   Just arrived at Pro Sports Cars, Fiat 500 Pop ...
# 9   Electric car at €100 per month: we’re almost t...
# 10  RT @BBC_TopGear: Here are 10 of the best small...
# 11  @Thierry_Boch Correct @Thierry_Boch! It's the ...
# 12  SUMMER JUST GOT ELECTRIC ☀️⚡\n\nMissed the gov...
# 13                            https://t.co/xH60KY2wSu
# 14  日本でも免許不要だといいなあ。\n\nFIAT 500 に着想した2シーターの超小型 BEV...
# 15  ShinyShiny snippets: Fiat offers £300 e-grant ...
# ...

# %%
# Save dataframe as CSV
tweets_df11.to_csv('Fiat-electric.csv', index=False)

# %%
text_query = "Fiat 500"
max_tweets = 1000 # Maximum number of tweets to scrape

# %%
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

tweets_list = []
for tweet in tweets:
    tweets_list.append([tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, 
            tweet.user.default_profile_image])

# %%
tweets_df12 = pd.DataFrame(tweets_list, columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
tweets_df12.head(100)
# Out:
#                                            Tweet Text  \
# 0   Fiat 500 will never let molly go so who ever s...
# 1   RT @MigzerrDs: j’ai pris la fiat 500 vitré tei...
# 2           @mbbxo_ Fiat 500 twitter will be ecstatic
# 3   RT @decentralize___: listed zen bubble rider f...
# 4                                   @rojivvv Fiat 500
# ..                                                ...
# 95  RT @autoboomer: Last Drive of @FIATUSA 500 195...
# 96  The end of another great Fiat Freakout.\n\n@FI...
# 97  RT @ilhan_karasu: 500 tl lik manknot çıkacağın...
# 98  RT @ncky0_: He further expressed significant c...
# 99  RT @ilhan_karasu: 500 tl lik manknot çıkacağın...
#
#               Tweet Datetime             Tweet Id     Twitter Username  \
# 0  2023-06-11 15:26:24+00:00  1667916199135522816              Preshhy
# 1  2023-06-11 15:24:56+00:00  1667915828635860993             Issam GP
# 2  2023-06-11 15:23:50+00:00  1667915553128718336               Akosua
# ...

# %%
# Save dataframe as CSV
tweets_df12.to_csv('Fiat-500.csv', index=False)

# %%
text_query = "Fiat hybrid"
max_tweets = 1000 # Maximum number of tweets to scrape

# %%
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

tweets_list = []
for tweet in tweets:
    tweets_list.append([tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, 
            tweet.user.default_profile_image])

# %%
tweets_df13 = pd.DataFrame(tweets_list, columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
tweets_df13.head(100)
# Out:
#                                            Tweet Text  \
# 0   RT @clarethomps: What if 🤔 \n\nWadzPay + Circl...
# 1   @sturmtank That's why our Business Wallet Guid...
# 2   2021 FIAT 500 LOUNGE 1.0 MHEV EURO 6 AP 3DR\nS...
# 3   @Reptile_Hybrid Agree no one seems to give two...
# 4   RT @fiat: With Fiat Panda Hybrid &amp; 500 Hyb...
# 5   RT @clarethomps: What if 🤔 \n\nWadzPay + Circl...
# 6   RT @CryptoAzulene: @GRDecter Regulated #DeFi i...
# 7   RT @vaielettrico: Ancora una volta #Tesla batt...
# 8   @HondaCarIndia First You Should Fire Your Prod...
# 9   @HondaCarIndia First You Should Fire Your Prod...
# 10  @HondaCarIndia First You Should Fire Your Prod...
# 11  @HondaCarIndia First You Should Fire Your Prod...
# 12  @HondaCarIndia First You Should Fire Your Prod...
# 13  @HondaCarIndia First You Should Fire Your Prod...
# 14  @HondaCarIndia First You Should Fire Your Prod...
# 15  @HondaCarIndia First You Should Fire Your Prod...
# ...

# %%
# Save dataframe as CSV
tweets_df13.to_csv('Fiat-hybrid.csv', index=False)

# %%
text_query = "Fiat UK"
max_tweets = 500 # Maximum number of tweets to scrape

# %%
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

tweets_list = []
for tweet in tweets:
    tweets_list.append([tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, 
            tweet.user.default_profile_image])

# %%
tweets_df14 = pd.DataFrame(tweets_list, columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
tweets_df14.head(100)
# Out:
#                                            Tweet Text  \
# 0   @4thTroglodyte @hendry_hugh Then the currencie...
# 1                                       @FIAT_UK Nice
# 2                                       @FIAT_UK Nice
# 3   RT @milmodelscene: #WheelWednesday This week, ...
# 4   RT @milmodelscene: #WheelWednesday This week, ...
# ..                                                ...
# 95  RT @maneco1964: No, the UK is witnessing the r...
# 96  No, the UK is witnessing the result of @bankof...
# 97  SlotoCash Casino - New $5000 Freeroll Password...
# 98  Listen... #Banks do not want you to buy crypto...
# 99  RT @AutoExpress: Fiat 500 too small? You'll be...
#
#               Tweet Datetime             Tweet Id  \
# 0  2023-06-14 21:51:40+00:00  1669100318095712257
# 1  2023-06-14 21:39:12+00:00  1669097178025844736
# 2  2023-06-14 21:38:05+00:00  1669096900023181312
# 3  2023-06-14 21:27:26+00:00  1669094216511676417
# 4  2023-06-14 21:19:30+00:00  1669092222434959360
# ...

# %%
# Save dataframe as CSV
tweets_df14.to_csv('FiatUK1.csv', index=False)

# %%
text_query = "Fiat 500 UK"
max_tweets = 500 # Maximum number of tweets to scrape

# %%
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

tweets_list = []
for tweet in tweets:
    tweets_list.append([tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, 
            tweet.user.default_profile_image])

# %%
tweets_df15 = pd.DataFrame(tweets_list, columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
tweets_df15.head(100)
# Out:
#                                            Tweet Text  \
# 0   RT @AutoExpress: Fiat 500 too small? You'll be...
# 1   RT @AutoExpress: Fiat 500 too small? You'll be...
# 2   The North East's most popular used car is the ...
# 3   @anneramsey740 A fiat 500 1.2 popular is UK gr...
# 4   1971 Fiat 500 'Abarth L' - 695cc, looks like a...
# ..                                                ...
# 95  RT @audreythefinest: Most of us wouldn’t have ...
# 96  RT @audreythefinest: Most of us wouldn’t have ...
# 97  RT @audreythefinest: Most of us wouldn’t have ...
# 98  RT @audreythefinest: Most of us wouldn’t have ...
# 99  RT @audreythefinest: Most of us wouldn’t have ...
#
#               Tweet Datetime             Tweet Id   Twitter Username  \
# 0  2023-06-14 16:11:57+00:00  1669014823945011200              Cumคม
# 1  2023-06-14 16:09:36+00:00  1669014234108182529       Auto Express
# 2  2023-06-14 16:03:04+00:00  1669012589316063232  The Windscreen Co
# ...

# %%
# Save dataframe as CSV
tweets_df15.to_csv('FiatUK500.csv', index=False)

# %%
text_query = "Fiat sport UK "
max_tweets = 1000 # Maximum number of tweets to scrape

# %%
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

tweets_list = []
for tweet in tweets:
    tweets_list.append([tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, 
            tweet.user.default_profile_image])

# %%
tweets_df16 = pd.DataFrame(tweets_list, columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
tweets_df16.head(100)
# Out:
#                                           Tweet Text  \
# 0  Stock deals under £250 a month! 👌\n\nHere’s ou...
#
#              Tweet Datetime             Tweet Id      Twitter Username  \
# 0 2023-06-04 11:30:13+00:00  1665320046711668737  LeasingOptions.co.uk
#
#    Twitter @ name Twitter User Id Twitter User Location  \
# 0  LeasingOptions        21999229   Manchester, England
#
#                 URL in Bio                                        Twitter Bio  \
# 0  https://t.co/qgZZWAQj1F  The UK’s leading car leasing company deliverin...
#
#    User Verified Status  Users Following Count  \
# 0                 False                   4127
#
#    Number users this account is following  Users Number of Likes  \
# 0                                    3642                    898
#
#    Users Tweet Count  Lists Containing User      Account Created Time  \
# 0               4175                     31 2009-02-26 11:21:58+00:00
#
# ...

# %%
# Save dataframe as CSV
tweets_df16.to_csv('Fiat-x-500.csv', index=False)

# %%
text_query = "Abarth"
max_tweets = 1000 # Maximum number of tweets to scrape

# %%
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

tweets_list = []
for tweet in tweets:
    tweets_list.append([tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, 
            tweet.user.default_profile_image])

# %%
tweets_df17 = pd.DataFrame(tweets_list, columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
# Save dataframe as CSV
tweets_df17.to_csv('Abarth1.csv', index=False)

# %%
text_query = "Abarth UK"
max_tweets = 1000 # Maximum number of tweets to scrape

# %%
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

tweets_list = []
for tweet in tweets:
    tweets_list.append([tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, 
            tweet.user.default_profile_image])

# %%
tweets_df18 = pd.DataFrame(tweets_list, columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
tweets_df18.head()
# Out:
#                                           Tweet Text  \
# 0  Right, need to sell at least 8 of my cars. Che...
# 1  @rolandmcs "Stellantis, which also owns the Ci...
# 2  Driven by performance? Unleash the power of el...
# 3  This week's blog post explores the brand-new A...
# 4  There’s a new Scorpion in town. Meet the New A...
#
#              Tweet Datetime             Tweet Id  \
# 0 2023-06-13 18:05:11+00:00  1668680932935475211
# 1 2023-06-13 16:10:52+00:00  1668652163994664960
# 2 2023-06-12 18:08:19+00:00  1668319333347360775
# 3 2023-06-12 09:00:55+00:00  1668181575257714691
# 4 2023-06-12 07:58:03+00:00  1668165753672024064
#
#                          Twitter Username   Twitter @ name  \
# 0                           Colin Hagan 💙        scouse_us
# 1                          GarfieldTheCat  GarfieldTheCa15
# 2  FJ Chalke Electric Vehicle Specialists       FJChalkeEV
# 3                           Wilsons Epsom     wilsonsepsom
# ...

# %%
# Save dataframe as CSV
tweets_df18.to_csv('Abarth-UK.csv', index=False)

# %%
text_query = "Abarth 500"
max_tweets = 1000 # Maximum number of tweets to scrape

# %%
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

tweets_list = []
for tweet in tweets:
    tweets_list.append([tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, 
            tweet.user.default_profile_image])

# %%
tweets_df19 = pd.DataFrame(tweets_list, columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
tweets_df19.head(100)
# Out:
#                                            Tweet Text  \
# 0   @Copybytom Get a manual Fiat 500 Abarth. \n\nI...
# 1   Right, need to sell at least 8 of my cars. Che...
# 2   @AlexInter88 @alemarino71 @CalcioFinanza hai u...
# 3              @Matcha_ABARTH あなたのアタリマエと俺がきっとなって見せるから
# 4   RT @Xueza_00: buongiorno a tutti ho dimenticat...
# ..                                                ...
# 95  @solodax @mirkonicolino Secondo me il Toro si ...
# 96  6.500 dólares por un Duna 95 fabricado por Sev...
# 97  @sole_abarth 最近の夜のツイートが明らかにお酒入ってる感じしてたのでwww\n毎...
# 98                   @595TurismoMT @Matcha_ABARTH 🥺🥺🥺
# 99                 @Matcha_ABARTH @ryouta_500 来て欲しいな🥺
#
#               Tweet Datetime             Tweet Id  \
# 0  2023-06-13 20:45:46+00:00  1668721345566511104
# 1  2023-06-13 18:05:11+00:00  1668680932935475211
# 2  2023-06-13 16:25:20+00:00  1668655803656437760
# 3  2023-06-13 11:28:24+00:00  1668581077995368449
# 4  2023-06-13 10:35:32+00:00  1668567775743229953
# ...

# %%
# Save dataframe as CSV
tweets_df19.to_csv('Abarth-500.csv', index=False)

# %%
text_query = "Abarth Sport"
max_tweets = 1000 # Maximum number of tweets to scrape

# %%
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

tweets_list = []
for tweet in tweets:
    tweets_list.append([tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, 
            tweet.user.default_profile_image])

# %%
tweets_df20 = pd.DataFrame(tweets_list, columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
tweets_df20.head(100)
# Out:
#                                            Tweet Text  \
# 0   @Mumux_art @MayFeyu Mais non @Mumux_art trop a...
# 1   RT @RSF_Motorsport: 1968 #Fiat #Abarth 2000 Sp...
# 2   @MarksDoingGreat A tuned Saab 9-3 coupe around...
# 3   RT @ItaliAuto: #Fiat 🇮🇹 Abarth 1000 TC 🦂\n\n© ...
# 4   RT @ondacero_cs: 🎈🛞¡Gran Feria de Ocasión en @...
# 5   RT @ItaliAuto: #Fiat 🇮🇹 Abarth 1000 TC 🦂\n\n© ...
# 6   RT @ItaliAuto: #Fiat 🇮🇹 Abarth 1000 TC 🦂\n\n© ...
# 7   RT @ItaliAuto: #Fiat 🇮🇹 Abarth 1000 TC 🦂\n\n© ...
# 8   RT @ItaliAuto: #Fiat 🇮🇹 Abarth 1000 TC 🦂\n\n© ...
# 9   RT @ItaliAuto: #Fiat 🇮🇹 Abarth 1000 TC 🦂\n\n© ...
# 10  RT @ItaliAuto: #Fiat 🇮🇹 Abarth 1000 TC 🦂\n\n© ...
# 11  RT @ItaliAuto: #Fiat 🇮🇹 Abarth 1000 TC 🦂\n\n© ...
# 12  RT @ItaliAuto: #Fiat 🇮🇹 Abarth 1000 TC 🦂\n\n© ...
# 13  RT @ItaliAuto: #Fiat 🇮🇹 Abarth 1000 TC 🦂\n\n© ...
# 14  RT @ItaliAuto: #Fiat 🇮🇹 Abarth 1000 TC 🦂\n\n© ...
# 15  RT @ItaliAuto: #Fiat 🇮🇹 Abarth 1000 TC 🦂\n\n© ...
# ...

# %%
# Save dataframe as CSV
tweets_df20.to_csv('Abarth-sport.csv', index=False)

# %%
text_query = "Abarth cars"
max_tweets = 1000 # Maximum number of tweets to scrape

# %%
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

tweets_list = []
for tweet in tweets:
    tweets_list.append([tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, 
            tweet.user.default_profile_image])

# %%
tweets_df21 = pd.DataFrame(tweets_list, columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
tweets_df21.head(100)
# Out:
#                                            Tweet Text  \
# 0   Now live on Cars &amp; Bids: 2012 Fiat 500 Aba...
# 1   #Auto - little #EVs includes 3 you may want – ...
# 2   @Gregess76 @Tweddmeister Great cars, but a fir...
# 3   Despite there being electric cars of all shape...
# 4   RT @tamforrester: @SportsandGT Not my wedge bu...
# 5   @SportsandGT Not my wedge but my friends wee B...
# 6   Right, need to sell at least 8 of my cars. Che...
# 7   RT @officialenzari: How a Scorpion comes to li...
# 8   RT @officialenzari: How a Scorpion comes to li...
# 9   How a Scorpion comes to life: The Making of th...
# 10  @willz1to @DonJoewonSong Yeah there's some Toy...
# 11  @PatrickBMin Yeah! Just as cheap as the standa...
# 12  @perfectionvalet Richard - this looks superb (...
# 13  Good day Modena Yellow meets Adrenalin Green a...
# 14  Bonjour 😀\n\nL’article de l’Abarth 500e avec l...
# 15  @DarraghMcKenna @dougs_cars @CoreyLewis86 Conf...
# ...

# %%
# Save dataframe as CSV
tweets_df21.to_csv('Abarth-cars.csv', index=False)

# %%
text_query = "#Abarth"
max_tweets = 1000 # Maximum number of tweets to scrape

# %%
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

tweets_list = []
for tweet in tweets:
    tweets_list.append([tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, 
            tweet.user.default_profile_image])

# %%
tweets_df22 = pd.DataFrame(tweets_list, columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
tweets_df22.head(100)
# Out:
#                                            Tweet Text  \
# 0   RT @autostories_it: Abarth 1000 Monoposto Reco...
# 1   RT @fiat_fan_club: Fiat Abarth OT 2000 coupé  ...
# 2   RT @RSF_Motorsport: 1968 #Fiat #Abarth 2000 Sp...
# 3   RT @_FleetNews: @Stellantis brings eight brand...
# 4   @Stellantis brings eight brands to #CCIA2023\n...
# ..                                                ...
# 95  RT @satochee: 悲報😭\n\nアバルトのフロントガラス外れる😅\n\n#アバルト...
# 96  RT @satochee: 悲報😭\n\nアバルトのフロントガラス外れる😅\n\n#アバルト...
# 97  RT @satochee: 悲報😭\n\nアバルトのフロントガラス外れる😅\n\n#アバルト...
# 98  Szpak zareklamuje elektrycznego Abartha ⚡️http...
# 99  RT @satochee: 悲報😭\n\nアバルトのフロントガラス外れる😅\n\n#アバルト...
#
#               Tweet Datetime             Tweet Id       Twitter Username  \
# 0  2023-06-14 18:13:43+00:00  1669045466795855872        @motorespuntoes
# 1  2023-06-14 18:08:44+00:00  1669044212895997960        @motorespuntoes
# 2  2023-06-14 18:06:55+00:00  1669043757767852032        @motorespuntoes
# ...

# %%
# Save dataframe as CSV
tweets_df22.to_csv('Abarth#.csv', index=False)

# %%
text_query = "Abarth performance"
max_tweets = 1000 # Maximum number of tweets to scrape

# %%
tweets = tweepy.Cursor(api.search_tweets, q=text_query).items(max_tweets)

tweets_list = []
for tweet in tweets:
    tweets_list.append([tweet.text, tweet.created_at, tweet.id_str, tweet.user.name,
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location,
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count,
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count,
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, 
            tweet.user.default_profile_image])

# %%
tweets_df23 = pd.DataFrame(tweets_list, columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
tweets_df23.head(100)
# Out:
#                                            Tweet Text  \
# 0   Driven by performance? Unleash the power of el...
# 1   There’s a new Scorpion in town. Meet the New A...
# 2   RT @collectingcars_: An involving performance ...
# 3   RT @TeamAbarth: #Abarth always dressed perform...
# 4   (Le Télégramme): #Fiat #Abarth 500e Électrique...
# 5   RT @collectingcars_: An involving performance ...
# 6   An involving performance roadster, upgraded wi...
# 7   What do we have here? A full forge upgrade on ...
# 8   RT @whatcar: The Abarth 500e is arguably the f...
# 9   RT @whatcar: The Abarth 500e is arguably the f...
# 10  The Abarth 500e is arguably the first fully el...
#
#               Tweet Datetime             Tweet Id  \
# 0  2023-06-12 18:08:19+00:00  1668319333347360775
# 1  2023-06-12 07:58:03+00:00  1668165753672024064
# 2  2023-06-09 18:42:31+00:00  1667240775564795912
# 3  2023-06-09 17:43:28+00:00  1667225916425027584
# 4  2023-06-09 15:23:06+00:00  1667190591770226689
# ...

# %%
# Save dataframe as CSV
tweets_df23.to_csv('Abarth-performance.csv', index=False)

# %%
df1 = pd.read_csv('/Users/rutvajoshi/Documents/Masters final project/csv files /Fiat-cars.csv')
df2 = pd.read_csv('/Users/rutvajoshi/Documents/Masters final project/csv files /Fiat-electric.csv')

# %%
merged_df = pd.concat([df1, df2], axis=0)  # Merge vertically (rows)

# %%
merged_df.to_csv('mergedfiat.csv', index=False)

# %%
df3 = pd.read_csv('/Users/rutvajoshi/mergedfiat.csv')
df4 = pd.read_csv('/Users/rutvajoshi/Documents/Masters final project/csv files /Fiat-500.csv')

# %%
merged_df = pd.concat([df3, df4], axis=0)
merged_df.to_csv('fiat11.csv', index=False)

# %%
df5 = pd.read_csv('/Users/rutvajoshi/fiat11.csv')
df6 = pd.read_csv('/Users/rutvajoshi/Documents/Masters final project/csv files /Fiatautomobiles.csv')

# %%
merged_df = pd.concat([df5, df6], axis=0)
merged_df.to_csv('fiat12.csv', index=False)

# %%
df7 = pd.read_csv('/Users/rutvajoshi/fiat12.csv')
df8 = pd.read_csv('/Users/rutvajoshi/Documents/Masters final project/csv files /Fiat500x.csv')

# %%
merged_df = pd.concat([df7, df8], axis=0)
merged_df.to_csv('fiat13.csv', index=False)

# %%
df9 = pd.read_csv('/Users/rutvajoshi/fiat13.csv')
df10 = pd.read_csv('/Users/rutvajoshi/Documents/Masters final project/csv files /Fiatsports.csv')

# %%
merged_df = pd.concat([df9, df10], axis=0)
merged_df.to_csv('fiat14.csv', index=False)

# %%
df11 = pd.read_csv('/Users/rutvajoshi/fiat14.csv')
df12 = pd.read_csv('/Users/rutvajoshi/Documents/Masters final project/csv files /Fiat-hybrid.csv')

# %%
merged_df = pd.concat([df11, df12], axis=0)
merged_df.to_csv('fiat15.csv', index=False)

# %%
df13 = pd.read_csv('/Users/rutvajoshi/fiat15.csv')
df14 = pd.read_csv('/Users/rutvajoshi/FiatUK1.csv')

# %%
merged_df = pd.concat([df13, df14], axis=0)
merged_df.to_csv('fiat16.csv', index=False)

# %%
df15 = pd.read_csv('/Users/rutvajoshi/fiat16.csv')
df16 = pd.read_csv('/Users/rutvajoshi/Fiat500UK.csv')

# %%
merged_df = pd.concat([df15, df16], axis=0)
merged_df.to_csv('Final-Fiat.csv', index=False)

# %%
df17 = pd.read_csv('/Users/rutvajoshi/abarth11.csv')
df18= pd.read_csv('/Users/rutvajoshi/Documents/Masters final project/csv files /Abarth-UK.csv')

# %%
merged_df = pd.concat([df17, df18], axis=0)
merged_df.to_csv('abarth11.csv', index=False)

# %%
df19 = pd.read_csv('/Users/rutvajoshi/abarth11.csv')
df20= pd.read_csv('/Users/rutvajoshi/Documents/Masters final project/csv files /Abarth-sport.csv')

# %%
merged_df = pd.concat([df19, df20], axis=0)
merged_df.to_csv('abarth12.csv', index=False)

# %%
df21 = pd.read_csv('/Users/rutvajoshi/abarth12.csv')
df22= pd.read_csv('/Users/rutvajoshi/Documents/Masters final project/csv files /Abarth-500.csv')

# %%
merged_df = pd.concat([df21, df22], axis=0)
merged_df.to_csv('abarth13.csv', index=False)

# %%
df23 = pd.read_csv('/Users/rutvajoshi/abarth13.csv')
df24= pd.read_csv('/Users/rutvajoshi/Documents/Masters final project/csv files /Abarth-cars.csv')

# %%
merged_df = pd.concat([df23, df24], axis=0)
merged_df.to_csv('abarth14.csv', index=False)

# %%
df25 = pd.read_csv('/Users/rutvajoshi/abarth14.csv')
df26= pd.read_csv('/Users/rutvajoshi/Documents/Masters final project/csv files /Abarth#.csv')

# %%
merged_df = pd.concat([df25, df26], axis=0)
merged_df.to_csv('Final-abarth.csv', index=False)

# %%
df27 = pd.read_csv('/Users/rutvajoshi/Final-abarth.csv')
df28= pd.read_csv('/Users/rutvajoshi/Documents/Masters final project/csv files /Abarth-performance.csv')

# %%
merged_df = pd.concat([df27, df28], axis=0)
merged_df.to_csv('Final-abarth500.csv', index=False)

# %%
CONSUMER_API_KEY  
CONSUMER_API_SECRET  
ACCESS_KEY  
ACCESS_SECRET
